# %% [markdown]
# # Geting dataset from roboflow

# %%
API_KEY = "4DY3M1C2vojgqtpWxnM6"

# %%
# !pip install roboflow

# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.8/883.8 kB 21.1 MB/s eta 0:00:0000:01
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key=API_KEY)

project = rf.workspace("tenisdb").project("tennis-ball-detection-sxi3e")

version = project.version(1)

dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tennis-ball-detection-1 in yolov11:: 100%|██████████| 1168/1168 [00:00<00:00, 5497.46it/s]

# %%
# to move and copy files and folders

import shutil

# %%
shutil.move("tennis-ball-detection-1/tennis-ball-detection-1/train",
            "tennis-ball-detection-1/train")



shutil.move("tennis-ball-detection-1/tennis-ball-detection-1/test",
            "tennis-ball-detection-1/test")



shutil.move("tennis-ball-detection-1/tennis-ball-detection-1/valid",
            "tennis-ball-detection-1/valid")
# Out:
# 'tennis-ball-detection-1/valid'

# %%
# !yolo task=detect mode=train model=yolo11x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...
